# %%
from bs4 import BeautifulSoup
import requests

url = "www.google.com/search?q=Wyndham+Garden+San+Jose+Silicon+Valley"

r  = requests.get("http://" +url)

data = r.text

soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://www.google.com/search?hl=en&tbm=isch&source=og&tab=wi
# http://maps.google.com/maps?hl=en&tab=wl
# https://play.google.com/?hl=en&tab=w8
# http://www.youtube.com/results?tab=w1
# http://news.google.com/nwshp?hl=en&tab=wn
# https://mail.google.com/mail/?tab=wm
# https://drive.google.com/?tab=wo
# https://www.google.com/intl/en/options/
# http://www.google.com/history/optout?hl=en
# /preferences?hl=en
# https://accounts.google.com/ServiceLogin?hl=en&passive=true&continue=http://www.google.com/search%3Fq%3DWyndham%2BGarden%2BSan%2BJose%2BSilicon%2BValley
# /webhp?hl=en
# /search?q=Wyndham+Garden+San+Jose+Silicon+Valley&ie=UTF-8&prmd=ivns&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjrhM7i9JHPAhWBbCYKHcsjBiMQ_AUIBQ
# /search?q=Wyndham+Garden+San+Jose+Silicon+Valley&ie=UTF-8&prmd=ivns&source=lnms&tbm=vid&sa=X&ved=0ahUKEwjrhM7i9JHPAhWBbCYKHcsjBiMQ_AUIBg
# /search?q=Wyndham+Garden+San+Jose+Silicon+Valley&ie=UTF-8&prmd=ivns&source=lnms&tbm=nws&sa=X&ved=0ahUKEwjrhM7i9JHPAhWBbCYKHcsjBiMQ_AUIBw
# ...
